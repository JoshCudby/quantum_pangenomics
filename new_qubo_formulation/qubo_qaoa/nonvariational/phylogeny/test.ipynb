# %%
import pickle

# %%
with open('./64v_pauli.pickle', 'rb') as f:
    data = pickle.load(f)

# %%
import numpy as np

# %%
sum(np.abs(data.coeffs))
# Out:
# np.float64(702.6666666666663)

# %%
np.abs(sum(data.coeffs))
# Out:
# np.float64(202.6666666666663)
